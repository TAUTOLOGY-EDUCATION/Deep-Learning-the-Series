# %% [markdown]
# # 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (
    OrdinalEncoder, 
    OneHotEncoder, 
    StandardScaler, 
    MinMaxScaler
)
import torch
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
import os
import sys

lib_path = os.path.abspath('../../../lib')
sys.path.append(lib_path)

from easy_pytorch import PytorchMLPClassifier, make_confusion_matrix

# %%
seed = 12345

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# # 2. Read Data

# %%
data = pd.read_csv('../sound_to_csv/voice_command_dataset.csv')

data
# Out:
#         pixel_0    pixel_1    pixel_2    pixel_3    pixel_4    pixel_5  \
# 0    -80.000000 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000
# 1    -80.000000 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000
# 2    -80.000000 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000
# 3    -80.000000 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000
# 4    -62.529934 -62.529934 -62.529934 -62.152111 -61.512722 -60.873333
# ...         ...        ...        ...        ...        ...        ...
# 9499 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000
# 9500 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000
# 9501 -71.944351 -71.944351 -71.944351 -71.608337 -71.039703 -70.471054
# 9502 -71.259109 -71.259109 -71.259109 -70.686661 -69.717888 -68.749115
# 9503 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000 -80.000000
#
#         pixel_6    pixel_7    pixel_8    pixel_9  ...  pixel_8183  pixel_8184  \
# 0    -80.000000 -80.000000 -80.000000 -80.000000  ...       -80.0       -80.0
# 1    -80.000000 -80.000000 -80.000000 -80.000000  ...       -80.0       -80.0
# 2    -80.000000 -80.000000 -80.000000 -80.000000  ...       -80.0       -80.0
# 3    -80.000000 -80.000000 -80.000000 -80.000000  ...       -80.0       -80.0
# 4    -60.233940 -59.594551 -58.955162 -58.632915  ...       -80.0       -80.0
# ...         ...        ...        ...        ...  ...         ...         ...
# 9499 -80.000000 -80.000000 -80.000000 -80.000000  ...       -80.0       -80.0
# 9500 -80.000000 -80.000000 -80.000000 -80.000000  ...       -80.0       -80.0
# 9501 -69.902420 -69.333778 -68.765137 -68.614075  ...       -80.0       -80.0
# 9502 -67.780342 -66.811569 -65.842796 -66.136719  ...       -80.0       -80.0
# 9503 -80.000000 -80.000000 -80.000000 -80.000000  ...       -80.0       -80.0
#
#       pixel_8185  pixel_8186  pixel_8187  pixel_8188  pixel_8189  pixel_8190  \
# 0          -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 1          -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 2          -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 3          -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 4          -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# ...          ...         ...         ...         ...         ...         ...
# 9499       -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 9500       -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 9501       -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 9502       -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
# 9503       -80.0       -80.0       -80.0       -80.0       -80.0       -80.0
#
#       pixel_8191  label
# 0          -80.0     go
# 1          -80.0     go
# 2          -80.0     go
# 3          -80.0     go
# 4          -80.0     go
# ...          ...    ...
# 9499       -80.0    yes
# 9500       -80.0    yes
# 9501       -80.0    yes
# 9502       -80.0    yes
# 9503       -80.0    yes
#
# [9504 rows x 8193 columns]

# %% [markdown]
# # 3. Clean Data

# %% [markdown]
# ## 3.1. Handle Missing Values

# %% [markdown]
# ### 3.1.1. Check Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9504 entries, 0 to 9503
# Columns: 8193 entries, pixel_0 to label
# dtypes: float64(8192), object(1)
# memory usage: 594.1+ MB

# %% [markdown]
# ### 3.1.2. Remove Missing Values

# %%
# no NaN to remove
# data.dropna(axis=0, inplace=True)

# %% [markdown]
# ## 3.2. Handle Outliers

# %% [markdown]
# ### 3.2.1. Check Outliers

# %%
data.describe()
# Out:
#            pixel_0      pixel_1      pixel_2      pixel_3      pixel_4  \
# count  9504.000000  9504.000000  9504.000000  9504.000000  9504.000000
# mean    -74.196901   -74.196901   -74.196901   -74.111060   -73.951679
# std      12.805863    12.805863    12.805863    12.864995    12.999738
# min     -80.000008   -80.000008   -80.000008   -80.000008   -80.000008
# 25%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# 50%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# 75%     -76.969191   -76.969191   -76.969191   -76.658869   -76.080811
# max      -0.173088    -0.173088    -0.173088    -0.173088    -0.173088
#
#            pixel_5      pixel_6      pixel_7      pixel_8      pixel_9  ...  \
# count  9504.000000  9504.000000  9504.000000  9504.000000  9504.000000  ...
# mean    -73.788371   -73.624398   -73.460246   -73.296075   -73.265710  ...
# std      13.162878    13.350508    13.561792    13.795588    13.801340  ...
# min     -80.000008   -80.000008   -80.000008   -80.000008   -80.000008  ...
# 25%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000  ...
# 50%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000  ...
# 75%     -75.448872   -74.956299   -74.506472   -74.175171   -74.098099  ...
# max      -0.173088    -0.173088    -0.173088    -0.173088    -0.173088  ...
#
#         pixel_8182   pixel_8183   pixel_8184   pixel_8185   pixel_8186  \
# count  9504.000000  9504.000000  9504.000000  9504.000000  9504.000000
# mean    -79.719772   -79.719772   -79.719772   -79.719772   -79.719772
# std       3.642860     3.642860     3.642860     3.642860     3.642860
# min     -80.000008   -80.000008   -80.000008   -80.000008   -80.000008
# 25%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# 50%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# 75%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# max      -0.173088    -0.173088    -0.173088    -0.173088    -0.173088
#
#         pixel_8187   pixel_8188   pixel_8189   pixel_8190   pixel_8191
# count  9504.000000  9504.000000  9504.000000  9504.000000  9504.000000
# mean    -79.719772   -79.719772   -79.719772   -79.719772   -79.719772
# std       3.642860     3.642860     3.642860     3.642860     3.642860
# min     -80.000008   -80.000008   -80.000008   -80.000008   -80.000008
# 25%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# 50%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# 75%     -80.000000   -80.000000   -80.000000   -80.000000   -80.000000
# max      -0.173088    -0.173088    -0.173088    -0.173088    -0.173088
#
# [8 rows x 8192 columns]

# %% [markdown]
# ### 3.2.2. Remove Outliers

# %%
# no outlier to remove

# %% [markdown]
# # 4. Split Dataset into Training & Test Sets

# %%
target_name = 'label'
feature_name = list(data.columns.drop(target_name))

# %%
X = data[feature_name]
y = data[target_name]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=True)

# %% [markdown]
# # 5. Data Preparation

# %% [markdown]
# ## ### 5.1. Ordinal Encoding

# %% [markdown]
# ## ### 5.2. One Hot Encoding

# %% [markdown]
# ## 5.3. Feature Scaling

# %% [markdown]
# ### 5.3.1. Training Set

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %% [markdown]
# ### 5.3.2. Test Set

# %%
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # 6. Model Creation

# %% [markdown]
# ## 6.1. Setting Parameters

# %%
classes = np.unique(y_train)

# %%
clf = PytorchMLPClassifier(
    input_dim=X_train_scaled.shape[1],
    hidden_layer_sizes=(5, 5),
    activation_function='relu',
    classes=classes,
    learning_rate_init=0.0001,
    epochs=100,
    validation_split=0.1,
    use_gpu=True,
    class_weight='balanced',
    l1_lambda=0.0,
    l2_lambda=0.001,
    dropout_rate=[0, 0],
    solver='adam',
    batch_size=64
)

# %% [markdown]
# ## 6.2. Train Model

# %%
clf.fit(X_train_scaled, y_train)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'loss': [1.3550917879443303,
#   1.245288048949197,
#   1.1743065731547704,
#   1.1185414334323918,
#   1.0718249522636984,
#   1.0327815090384438,
#   0.9998717792680331,
#   0.9715999403846598,
#   0.9456146504277381,
#   0.9212253310970057,
#   0.8978536507793676,
#   0.8758966276578815,
#   0.8553831599583136,
#   0.8358617814901833,
#   0.8178082815954618,
#   0.8004883722724202,
#   0.7847507735279119,
#   0.7701043469883572,
#   0.7569332924958702,
#   0.7451498926242935,
#   0.7349454214639752,
#   0.7257972203682517,
#   0.7151689919355874,
#   0.707203308277041,
#   0.6993449486304666,
#   0.6735879182815552,
#   0.66986083984375,
#   0.6707183718681335,
#   0.6688535213470459,
#   0.6728186011314392,
#   0.6708351373672485,
#   0.6696464419364929,
#   0.6696528196334839,
#   0.6647218465805054,
#   0.6665726900100708,
#   0.6682229042053223,
#   0.6664106249809265,
#   0.6679206490516663,
#   0.6643494963645935,
#   0.6639021039009094,
#   0.6634923815727234,
#   0.658814549446106,
#   0.6658909320831299,
#   0.6621399521827698,
#   0.6624596118927002,
#   0.6625556349754333,
#   0.6609235405921936,
#   0.659995436668396,
#   0.6610759496688843,
#   0.6598312854766846,
#   0.6614940762519836,
#   0.6592302918434143,
#   0.65450519323349,
#   0.6544257402420044,
#   0.6591545939445496,
#   0.6528695821762085,
#   0.6574893593788147,
#   0.6567448973655701,
#   0.6577911376953125,
#   0.6555172801017761,
#   0.6548715829849243]}

# %% [markdown]
# ## 6.3. Loss Curve

# %%
plt.plot(clf.loss_curve_, label='training_loss')
plt.plot(clf.val_loss_curve_, label='validation_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()

# %% [markdown]
# ## 6.4. Model's Weight & Bias

# %%
for coef_ in clf.coefs_:
    print(coef_.shape)
# Out:
# (8192, 5)
# (5, 5)
# (5, 4)

# %%
for intercept_ in clf.intercepts_:
    print(intercept_.shape)
# Out:
# (5,)
# (5,)
# (4,)

# %% [markdown]
# # 7. Prediction

# %% [markdown]
# ## 7.1. Training Set

# %%
y_pred_train = clf.predict(X_train_scaled)

# %% [markdown]
# ## 7.2. Test Set

# %%
y_pred_test = clf.predict(X_test_scaled)

# %% [markdown]
# # 8. Model Evaluation

# %% [markdown]
# ## 8.1. Training Set

# %% [markdown]
# ### 8.1.1. Confusion Matrix

# %%
cm = confusion_matrix(y_train, y_pred_train)
make_confusion_matrix(
    cm,
    cmap='viridis',
    categories=classes,
    sum_stats=False,
    percent=False,
)
plt.show()

# %% [markdown]
# ### 8.1.2. Scoring

# %%
report = classification_report(y_train, y_pred_train, output_dict=True)

# %%
pd.DataFrame.from_dict(report).T
# Out:
#               precision    recall  f1-score     support
# go             0.674335  0.682359  0.678323  1933.00000
# no             0.672210  0.657398  0.664721  1906.00000
# stop           0.876842  0.883820  0.880317  1885.00000
# yes            0.910781  0.912720  0.911749  1879.00000
# accuracy       0.782980  0.782980  0.782980     0.78298
# macro avg      0.783542  0.784074  0.783778  7603.00000
# weighted avg   0.782445  0.782980  0.782682  7603.00000

# %% [markdown]
# ## 8.2. Test Set

# %% [markdown]
# ### 8.2.1. Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred_test)
make_confusion_matrix(
    cm,
    cmap='viridis',
    categories=classes,
    sum_stats=False,
    percent=False,
)
plt.show()

# %% [markdown]
# ### 8.2.2. Scoring

# %%
report = classification_report(y_test, y_pred_test, output_dict=True)

# %%
pd.DataFrame.from_dict(report).T
# Out:
#               precision    recall  f1-score      support
# go             0.607516  0.662870  0.633987   439.000000
# no             0.621924  0.592751  0.606987   469.000000
# stop           0.875264  0.836364  0.855372   495.000000
# yes            0.870518  0.877510  0.874000   498.000000
# accuracy       0.746975  0.746975  0.746975     0.746975
# macro avg      0.743805  0.742374  0.742586  1901.000000
# weighted avg   0.749687  0.746975  0.747848  1901.000000

# %% [markdown]
# # 9. Save Model

# %%
clf.save_model('voice_command_model')

# %%
import pickle

# %%
pickle.dump((scaler), open('voice_command_env.pickle', 'wb'))
